# %% [markdown]
# <a href="https://colab.research.google.com/github/afzalvu409-collab/Tic-Tac-Toe-game/blob/main/Untitled31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel("/content/reviews text dataset.xlsx")
df.head(10)
# Out:
#                                               review  class
# 0  Fantastic spot for an even or a quite cocktail...      1
# 1  Love, love, love the calamari. It's so good an...      1
# 2  Love this place. Stiff martinis and cocktails,...      1
# 3  It's everything a great cocktail bar should be...      1
# 4  I came here before a pirates game, so it was a...      1
# 5  Olive or Twist is the historic site of my VERY...      1
# 6  A beautiful little bar with an exciting "marti...      1
# 7  My favorite bar in town love the live music an...      1
# 8  The location is in a strip mall, but this plac...      1
# 9  THIS PLACE IS OPEN!The best food and the best ...      1

# %%
import re

# %%
clean_text = re.sub(r'[^a-zA-Z ]', '', df['review'][5])
clean_text
# Out:
# 'Olive or Twist is the historic site of my VERY FIRST MARTINI when I turned  many years ago  Its been a long happy unionWhile Olive or Twist is NOT a five star restaurant it gets  stars from me because I love it  Its one of the few places I know of that has been CONSISTANTLY good  for years  The interior is warm and a little bit industrial  The downstairs is the same as it has always been and its still very niceThe drinks are great although the first martini I ever had a girl doesnt forget  wellthis one didnt was a Pineapple Upside Down martini and I dont think they offer that anymore but they do have a very expansive martini menu  I tried the chipotle martini and it was so excellent that when I took my first sip I sighed in a way my bf turned to me and sarcastically said Oh youre going to be Yelping about that arent you  Then I refused to let him even try it bc it was that good  It was MINEI also had a cake batter martini which tasted great and came out looking so pretty I instagram
# ...

# %%
chunks = df['review'].str.split('.')
chunks
# Out:
# 0      [Fantastic spot for an even or a quite cocktai...
# 1      [Love, love, love the calamari,  It's so good ...
# 2      [Love this place,  Stiff martinis and cocktail...
# 3      [It's everything a great cocktail bar should b...
# 4      [I came here before a pirates game, so it was ...
#                              ...
# 103    [First rate bar food, better than many restaur...
# 104    [These are the best chicken strips I have ever...
# 105    [Great pizza on mondays deal!4, 99 for a large...
# 106    [This was one of my top places to go on campus...
# 107    [Cheap, amazing chicken strips, Everything els...
# Name: review, Length: 108, dtype: object

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize
tokens = df['review'].apply(word_tokenize)
print(tokens)
# Out:
# 0      [Fantastic, spot, for, an, even, or, a, quite,...
# 1      [Love, ,, love, ,, love, the, calamari, ., It,...
# 2      [Love, this, place, ., Stiff, martinis, and, c...
# 3      [It, 's, everything, a, great, cocktail, bar, ...
# 4      [I, came, here, before, a, pirates, game, ,, s...
#                              ...
# 103    [First, rate, bar, food, ,, better, than, many...
# 104    [These, are, the, best, chicken, strips, I, ha...
# 105    [Great, pizza, on, mondays, deal, !, 4.99, for...
# 106    [This, was, one, of, my, top, places, to, go, ...
# 107    [Cheap, ,, amazing, chicken, strips.Everything...
# Name: review, Length: 108, dtype: object

# %%
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 36.6 MB/s eta 0:00:00
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import faiss
import numpy as np

# %%
vectorizer = CountVectorizer()
vectors = vectorizer.fit_transform(df['review'])
vector = vectors.toarray()
d = vector.shape[1]
index = faiss.IndexFlatL2(d)
index.add(vector)
similarity = cosine_similarity(vector)
print(similarity)
# Out:
# [[1.         0.27650502 0.25559932 ... 0.32507714 0.43611285 0.3086067 ]
#  [0.27650502 1.         0.4656202  ... 0.4256341  0.4634339  0.29280349]
#  [0.25559932 0.4656202  1.         ... 0.28435071 0.31211641 0.25767356]
#  ...
#  [0.32507714 0.4256341  0.28435071 ... 1.         0.49435835 0.3251143 ]
#  [0.43611285 0.4634339  0.31211641 ... 0.49435835 1.         0.51990594]
#  [0.3086067  0.29280349 0.25767356 ... 0.3251143  0.51990594 1.        ]]
