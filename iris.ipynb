# %% [markdown]
# <a href="https://colab.research.google.com/github/afzalvu409-collab/Tic-Tac-Toe-game/blob/main/iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
iris = datasets.load_iris()
x = iris.data
y = iris.target
# x
# y
train_x, test_x, train_y, test_y = train_test_split(x,y, test_size=0.2, random_state=42)
# train_x
# test_x
# train_y
# test_y
model = linear_model.LogisticRegression()
model.fit(train_x, train_y)
pred = model.predict(test_x)
# pred
error = mean_squared_error(test_y, pred)
# error
from sklearn.metrics import accuracy_score

acc = accuracy_score(test_y, pred)
print(acc)
# graph
# plt.scatter(test_y, pred)
plt.bar(test_y, pred)

plt.xlabel("Actual")
plt.ylabel("Predicted")

plt.title("Actual vs Predicted")

plt.show()
# Out:
# 1.0
